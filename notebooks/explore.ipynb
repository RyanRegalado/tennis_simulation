# %%
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('..\\data\\probability_sweep.csv')

sns.set_theme(style="whitegrid")

point_prob = sns.barplot(x=df['point_win_probability'], y=df['expected_match_win_rate'])
plt.show()
